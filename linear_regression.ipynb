# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Alex Christopher\OneDrive\Desktop\Modular\ML_Live_Class\data\advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df["total_spent"] = df["TV"] + df["Radio"] + df["Newspaper"]
df.head()
# Out:
#       TV  Radio  Newspaper  Sales  total_spent
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3   12.0        132.4
# 3  151.5   41.3       58.5   16.5        251.3
# 4  180.8   10.8       58.4   17.9        250.0

# %%
sns.scatterplot(data=df, x="total_spent", y="Sales")
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='Sales'>

# %%
sns.regplot(data=df, x="total_spent", y="Sales", color="red")
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='Sales'>

# %%
x = df["total_spent"]
y = df["Sales"]

# %%
np.polyfit(x, y, deg=1)
# Out:
# array([0.0525585, 4.573573 ])

# %%
pf = np.polyfit(x, y, deg=3)
pf
# Out:
# array([ 4.49497819e-08, -7.06143726e-05,  7.48845278e-02,  2.94654345e+00])

# %%
potential_spend = np.linspace(1, 500, 100)
potential_spend
# Out:
# array([  1.        ,   6.04040404,  11.08080808,  16.12121212,
#         21.16161616,  26.2020202 ,  31.24242424,  36.28282828,
#         41.32323232,  46.36363636,  51.4040404 ,  56.44444444,
#         61.48484848,  66.52525253,  71.56565657,  76.60606061,
#         81.64646465,  86.68686869,  91.72727273,  96.76767677,
#        101.80808081, 106.84848485, 111.88888889, 116.92929293,
#        121.96969697, 127.01010101, 132.05050505, 137.09090909,
#        142.13131313, 147.17171717, 152.21212121, 157.25252525,
#        162.29292929, 167.33333333, 172.37373737, 177.41414141,
#        182.45454545, 187.49494949, 192.53535354, 197.57575758,
#        202.61616162, 207.65656566, 212.6969697 , 217.73737374,
#        222.77777778, 227.81818182, 232.85858586, 237.8989899 ,
#        242.93939394, 247.97979798, 253.02020202, 258.06060606,
#        263.1010101 , 268.14141414, 273.18181818, 278.22222222,
#        283.26262626, 288.3030303 , 293.34343434, 298.38383838,
# ...

# %%
# y=mx+c

prediction_sales = 0.0525585 * potential_spend + 4.573573
prediction_sales
# Out:
# array([ 4.6261315 ,  4.89104758,  5.15596365,  5.42087973,  5.6857958 ,
#         5.95071188,  6.21562795,  6.48054403,  6.74546011,  7.01037618,
#         7.27529226,  7.54020833,  7.80512441,  8.07004048,  8.33495656,
#         8.59987264,  8.86478871,  9.12970479,  9.39462086,  9.65953694,
#         9.92445302, 10.18936909, 10.45428517, 10.71920124, 10.98411732,
#        11.24903339, 11.51394947, 11.77886555, 12.04378162, 12.3086977 ,
#        12.57361377, 12.83852985, 13.10344592, 13.368362  , 13.63327808,
#        13.89819415, 14.16311023, 14.4280263 , 14.69294238, 14.95785845,
#        15.22277453, 15.48769061, 15.75260668, 16.01752276, 16.28243883,
#        16.54735491, 16.81227098, 17.07718706, 17.34210314, 17.60701921,
#        17.87193529, 18.13685136, 18.40176744, 18.66668352, 18.93159959,
#        19.19651567, 19.46143174, 19.72634782, 19.99126389, 20.25617997,
#        20.52109605, 20.78601212, 21.0509282 , 21.31584427, 21.58076035,
# ...

# %%
sns.scatterplot(data=df, x="total_spent", y="Sales")
plt.plot(potential_spend, prediction_sales, color="red")

# %%
pot_spent = np.linspace(1, 500, 100)

pred_sales = 4.49497819e-08*pot_spent**3 + -7.06143726e-05 * + pot_spent**2 + 7.48845278e-02*pot_spent**1 + 2.94654345e+00

pred_sales
# Out:
# array([ 3.02135741,  3.39630969,  3.76771535,  4.13560892,  4.50002494,
#         4.86099795,  5.21856248,  5.57275307,  5.92360425,  6.27115056,
#         6.61542654,  6.95646672,  7.29430564,  7.62897783,  7.96051784,
#         8.28896019,  8.61433943,  8.93669009,  9.25604671,  9.57244381,
#         9.88591595, 10.19649765, 10.50422346, 10.8091279 , 11.11124551,
#        11.41061084, 11.70725841, 12.00122276, 12.29253843, 12.58123996,
#        12.86736188, 13.15093872, 13.43200503, 13.71059534, 13.98674418,
#        14.2604861 , 14.53185563, 14.8008873 , 15.06761565, 15.33207522,
#        15.59430054, 15.85432615, 16.11218659, 16.36791639, 16.62155009,
#        16.87312222, 17.12266732, 17.37021993, 17.61581459, 17.85948582,
#        18.10126817, 18.34119617, 18.57930436, 18.81562727, 19.05019945,
#        19.28305542, 19.51422972, 19.7437569 , 19.97167147, 20.19800799,
#        20.42280099, 20.64608501, 20.86789457, 21.08826422, 21.30722849,
# ...

# %%
sns.scatterplot(data=df, x="total_spent", y="Sales")

plt.plot(pot_spent, pred_sales, color="green")

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 6))

axes[0].plot(df["TV"], df["Sales"], "o")
axes[0].set_ylabel("Sales")
axes[0].set_title("TV and Sales")


axes[1].plot(df["Radio"], df["Sales"], "o")
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio and Sales")


axes[2].plot(df["Newspaper"], df["Sales"], "o")
axes[2].set_ylabel("Sales")
axes[2].set_title("Newspaper and Sales")
# Out:
# Text(0.5, 1.0, 'Newspaper and Sales')

# %%
sns.pairplot(df)

# %%
x = df.drop(["Sales", "total_spent"], axis = 1)
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df["Sales"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_pred = model.predict(X_test)

# %%
test_pred
# Out:
# array([13.84736062, 21.6208545 , 12.4506434 , 15.53800991,  9.13572388,
#         7.32848067, 22.13382615, 18.99389515, 12.5074889 , 20.10480143,
#        11.14471789, 16.00799576, 17.13131444, 20.51391413, 18.52689489,
#         9.81871779, 19.29995509, 10.02472134,  8.55196221, 21.07099084,
#         7.84483773, 18.13469703, 24.90087497, 23.23638138,  9.50153866,
#        15.6580894 , 23.83636942,  8.88965111, 14.71191831, 10.08773315,
#         9.28121309, 20.03204425, 12.50942245,  6.7209499 , 17.73745681,
#         9.90528961, 10.54065531, 10.3248605 ,  9.01341274, 13.48442892,
#        11.40463282, 12.32027425, 11.24446527,  7.66448064, 11.63858892,
#        10.59311539,  8.22759878, 18.42554295, 15.2491901 , 20.20019412,
#        11.07711531, 16.71290321, 20.96270351, 12.69856152, 15.72864026,
#         6.15801816, 24.13296025, 11.37314587, 21.46171542, 16.49013139,
#        16.70390396, 24.54896417,  9.00346399, 19.27803416, 16.88593651,
#        21.81240684])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
sns.histplot(data = df, x="Sales", bins=20)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %%
mean_absolute_error(y_test, test_pred)
# Out:
# 1.421722777623365

# %%
mean_squared_error(y_test, test_pred)
# Out:
# 3.082137309967573

# %%
r2_score(y_test, test_pred)
# Out:
# 0.8953252136294944

# %%
np.sqrt(mean_squared_error(y_test, test_pred))
# Out:
# 1.7556016945672992

# %%
test_residuals = y_test - test_pred
test_residuals
# Out:
# 37     0.852639
# 109   -1.820855
# 31    -0.550643
# 89     1.161990
# 66     1.864276
#          ...
# 183    1.651036
# 127    2.896536
# 53     1.921966
# 100   -0.185937
# 93     0.387593
# Name: Sales, Length: 66, dtype: float64

# %%
sns.scatterplot(x=y_test, y=test_residuals)
plt.axhline(y=0, color="red", ls="--")

# %%
sns.displot(test_residuals, bins=25, kde=True)

# %%
y_hat = model.predict(x)

# %%
fig,axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6))

axes[0].plot(df['TV'], df['Sales'], 'o')
axes[0].plot(df['TV'], y_hat, 'o', color='red')
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].plot(df['Radio'], df['Sales'], 'o')
axes[1].plot(df['Radio'],y_hat, 'o', color='red')
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio Spend")

axes[2].plot(df['Newspaper'], df['Sales'], 'o')
axes[2].plot(df['Newspaper'],y_hat, 'o', color='red')
axes[2].set_ylabel("Sales")
axes[2].set_title("Newspaper spend")
# Out:
# Text(0.5, 1.0, 'Newspaper spend')

# %%
from joblib import dump, load  #Saving the file in binary form

# %%
import os

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'model.joblib')
dump(model, filepath)
# Out:
# ['models\\model.joblib']

# %%
load_model = load(r"C:\Users\Alex Christopher\OneDrive\Desktop\Modular\ML_Live_Class\models\model.joblib")

# %%
load_model.coef_
# Out:
# array([ 0.05475947,  0.11110453, -0.00941068])

# %%
example = [[151, 25, 15]]

# %%
load_model.predict(example)
# Out:
# D:\Users\Alex Christopher\anaconda3\envs\mltest\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.6034657])

# %%
#Polynomial Regression

# %%
x1 = df.drop(["Sales", "total_spent"], axis=1)
x1.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
x1.shape
# Out:
# (200, 3)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_conv = PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_conv.fit(x1)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = poly_conv.transform(x)

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
x1.loc[0]
# Out:
# TV           230.1
# Radio         37.8
# Newspaper     69.2
# Name: 0, dtype: float64

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size = 0.33, random_state = 101)

# %%
model1 = LinearRegression()

# %%
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_pred = model1.predict(X_test)
test_pred
# Out:
# array([13.73729763, 21.18242466, 12.97653989, 16.27244745,  7.79428568,
#         6.47813374, 21.55709584, 19.05558564, 13.62613421, 20.39877403,
#         9.44075447, 16.42451527, 16.82940592, 22.24971165, 19.46358894,
#         8.90282654, 17.73280571, 11.31308152,  8.64294876, 21.57608009,
#         6.61232229, 19.00689629, 25.84046033, 23.74268557,  9.97077004,
#        15.75920731, 22.61124976,  9.32982871, 15.23795646,  8.6682003 ,
#         8.21736462, 20.36369594, 13.49526847,  6.14426598, 18.34430932,
#        11.23087521, 11.09784264, 11.33375233,  7.03022331, 14.41881459,
#        12.72794639, 13.40097257, 11.7977989 ,  6.79581202, 11.35779953,
#        10.41309567,  5.79923857, 17.90408814, 15.63037075, 21.726204  ,
#        10.06724947, 16.61367696, 18.91328201, 13.2336876 , 15.89845423,
#         5.17495242, 24.8538122 ,  9.64582131, 20.51131932, 16.82761506,
#        16.95408539, 24.61559276, 10.36701538, 20.73812635, 16.38802112,
#        22.01089092])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_pred)
MAE
# Out:
# 1.1665197484834124

# %%
MSE = mean_squared_error(y_test, test_pred)
MSE
# Out:
# 2.205682874607847

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 1.4851541585329946

# %%
model1.coef_
# Out:
# array([ 7.70942584e-02, -2.35636076e-02, -4.29758910e-03, -1.07610956e-04,
#         5.03238675e-04, -8.46542155e-05,  1.16071503e-03,  1.34058536e-04,
#         1.28654587e-04])

# %%
train_rmse_errors = []
test_rmse_errors = []

for d in range(1, 10):
    poly_converter = PolynomialFeatures(degree=d, include_bias=False)
    poly_features = poly_converter.fit_transform(x1)
    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size = 0.33, random_state = 41)

    model2 = LinearRegression()
    model2.fit(X_train, y_train)

    train_pred = model2.predict(X_train)
    test_pred = model2.predict(X_test)

    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred ))

    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [1.647064353110424,
#  1.357732404041988,
#  1.2714740334632852,
#  1.115137182888956,
#  0.8641458256149933,
#  0.7510511124583392,
#  7.607712589191127,
#  2.3705486486541187,
#  2.3073161653141074]

# %%
test_rmse_errors #Overfitting after 5th degree
# Out:
# [1.6492731822693185,
#  1.3221146086531075,
#  1.4555964462310154,
#  3.3309217911019164,
#  2.387593262335397,
#  66.91099060404727,
#  283.68518071196524,
#  4584.806273608013,
#  147776.17406266488]

# %%
plt.plot(range(1, 6), train_rmse_errors[:5], label = "TRAIN_RMSE")
plt.plot(range(1, 6), test_rmse_errors[:5], label = "TEST_RMSE")
plt.xlabel("MODEL COMPLEXITY")
plt.ylabel("ERRORS")
plt.legend()

# %%
plt.plot(range(1, 10), train_rmse_errors, label = "TRAIN_RMSE")
plt.plot(range(1, 10), test_rmse_errors, label = "TEST_RMSE")
plt.xlabel("MODEL COMPLEXITY")
plt.ylabel("ERRORS")
plt.legend()

# %%
final_poly_converter = PolynomialFeatures(degree=3, include_bias=False)

# %%
final_model = LinearRegression()

# %%
full_converted_x = final_poly_converter.fit_transform(x1)
final_model = final_model.fit(full_converted_x, y)

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'poly.joblib')
dump(final_model, filepath)
# Out:
# ['models\\poly.joblib']

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'converter.joblib')
dump(final_poly_converter, filepath)
# Out:
# ['models\\converter.joblib']

# %%
loded_converter = load(r"C:\Users\Alex Christopher\OneDrive\Desktop\Modular\ML_Live_Class\models\converter.joblib")
loaded_model = load(r"C:\Users\Alex Christopher\OneDrive\Desktop\Modular\ML_Live_Class\models\poly.joblib")

# %%
final_predicted = final_model.predict(full_converted_x)

# %%
pd.DataFrame({
    "Actual Values" : y,
    "Predicted Values" : final_predicted,
    "Precentage" : (final_predicted / y) * 100
})
# Out:
#      Actual Values  Predicted Values  Precentage
# 0             22.1         21.265354   96.223322
# 1             10.4         10.240473   98.466086
# 2             12.0          9.220530   76.837749
# 3             16.5         17.807602  107.924859
# 4             17.9         16.140340   90.169498
# ..             ...               ...         ...
# 195            7.6          7.573013   99.644911
# 196           14.0         11.779928   84.142339
# 197           14.8         16.273081  109.953247
# 198           25.5         24.893500   97.621568
# 199           18.4         17.866038   97.098034
#
# [200 rows x 3 columns]

# %%
r2score = r2_score(y, final_predicted)
r2score
# Out:
# 0.9409600764626057

# %%
mse = mean_squared_error(y, final_predicted)
mse
# Out:
# 1.6401243379149504

# %%
mae = mean_absolute_error(y, final_predicted)
mae
# Out:
# 0.928367701608913
